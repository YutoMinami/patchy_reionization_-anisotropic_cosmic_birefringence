# %% [markdown]
# # 17b corrected Dvorkin-Smith figure reproduction
#
# paper の Fig.16 ラベル `tau=0.084, 0.11` を使った corrected check です。

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

ROOT = Path('/home/yminami/workdir/CosmicBirefringence/PatchyReionization')
PAPERS = ROOT / 'papers'
RESULT = ROOT / 'results/17-ds-figure-check-corrected'
summary = pd.read_csv(RESULT / 'figure_reproduction_summary.csv')
summary

# %% [markdown]
# ## Paper p15 / p16

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 7))
axes[0].imshow(mpimg.imread(PAPERS / 'p15.png'))
axes[0].axis('off')
axes[0].set_title('paper p15')
axes[1].imshow(mpimg.imread(PAPERS / 'p16.png'))
axes[1].axis('off')
axes[1].set_title('paper p16')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Corrected Fig.16-like reproduction

# %%
plt.figure(figsize=(8,5.5))
plt.imshow(mpimg.imread(RESULT / 'fig16_like_corrected_v2.png'))
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Corrected Fig.18-like reproduction

# %%
plt.figure(figsize=(8,5.5))
plt.imshow(mpimg.imread(RESULT / 'fig18_like_corrected_v2.png'))
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## A-model vs paper labels

# %%
summary[summary['figure']=='fig16_like_corrected'][['tau','delta_y','A_model','A_paper','z_re','L_peak_surrogate']]

# %% [markdown]
# # 20b visualize A_tau normalization check
#
# raw `A_tau` が大きすぎる理由を、field normalization の missing factor として切り分ける notebook です。

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

ROOT = Path('/home/yminami/workdir/CosmicBirefringence/PatchyReionization')
RESULT = ROOT / 'results/20-atau-normalization-check'
summary = pd.read_csv(RESULT / 'atau_normalization_summary.csv')
summary

# %% [markdown]
# ## Required field-unit factor

# %%
plt.figure(figsize=(8,5.5))
plt.imshow(mpimg.imread(RESULT / 'uphi_required_vs_L.png'))
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Peak summary

# %%
summary[['g_GeV_inv','A_tau_raw_code_units','A_tau_naive_if_uphi_eq_1','C_alphaalpha_peak_naive_if_uphi_eq_1','Uphi_limit_peak']]

# %% [markdown]
# ## Reading guide
#
# - `U_phi_limit_peak` は、今の code-field にどれだけの unit factor を掛ければ limit ちょうどになるか、という量です。
# - これが極端なら、`g` を今の `phi_amp_max` にそのまま掛けるのは不自然です。
# - つまり本当に怪しいのは patchy physics そのものより field normalization です。

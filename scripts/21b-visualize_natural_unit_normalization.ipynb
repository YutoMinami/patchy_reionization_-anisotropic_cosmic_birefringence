# %% [markdown]
# # 21b visualize natural-unit normalization
#
# matched background から作っていた量を、自然単位系で読み直したときにどう変わるかを見る notebook です。

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

ROOT = Path('/home/yminami/workdir/CosmicBirefringence/PatchyReionization')
RESULT = ROOT / 'results/21-natural-unit-normalization'
summary = pd.read_csv(RESULT / 'natural_unit_summary.csv')
summary

# %% [markdown]
# ## Quantity comparison

# %%
plt.figure(figsize=(8,5.5))
plt.imshow(mpimg.imread(RESULT / 'natural_unit_bar_summary.png'))
plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Numeric summary

# %%
summary[['phi_amp_max_old_code_units','phi_amp_max_nat_GeV','A_unit_old_mixed','A_unit_nat_GeV','A_tau_raw_nat_GeV','g_GeV_inv','A_tau_physical_dimless']]

# %% [markdown]
# ## Reading guide
#
# - old と nat が大きく違えば、問題の本体は field normalization / unit conversion です。
# - 最後の `A_tau_physical_dimless` が本当に small になるなら、`19` の huge budget は mixed-unit artifact だった可能性が高いです。
